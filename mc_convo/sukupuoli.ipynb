# %%
from PIL import Image
import numpy as np

# %%
img = Image.open('mikä.jpg').convert('LA')

# %%
img.save('harmaa.png')

# %%
väri=Image.open("mikä.jpg").convert("RGB")

# %%
np.shape(väri)
# Out:
# (2048, 945, 3)

# %%
väri
# Out:
# <PIL.Image.Image image mode=RGB size=945x2048>

# %%
backtorgb = cv2.cvtColor(gray,cv2.COLOR_GRAY2RBG)

plt.imshow(backtorgb)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 backtorgb = cv2.cvtColor(gray,cv2.COLOR_GRAY2RBG)
#       3 plt.imshow(backtorgb)
#       4 plt.show()
#
# AttributeError: module 'cv2' has no attribute 'COLOR_GRAY2RBG'

# %%
gray = image[:,:,::-1]
plt.imshow(gray)
plt.title("gray")
plt.show()

# %%
backtorgb = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)
plt.imshow(backtorgb)
plt.title("backtorgb")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 backtorgb = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)
#       2 plt.imshow(backtorgb)
#       3 plt.title("backtorgb")
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<1>; VDcn = cv::impl::{anonymous}::Set<3, 4>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = cv::impl::<unnamed>::NONE; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 3
